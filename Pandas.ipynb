# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhayanidhi-96/Data-science-works/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
import pandas as pd

# %% [markdown]
# **Data frames**
#
# Data Frame is like a tables

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=["A","B","C"],index=["x","y","z"])
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.tail(1)
# Out:
#    A  B  C
# z  7  8  9

# %% [markdown]
# ###Returns the index of the column

# %%
df.index.tolist()
# Out:
# ['x', 'y', 'z']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %% [markdown]
# It shows the unique values in the specfic column

# %%
df["A"].nunique()
# Out:
# 3

# %%
df.shape
# Out:
# (3, 3)

# %% [markdown]
# To seee the total number of items

# %%
df.size
# Out:
# 9

# %%
coffee = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/warmup-data/coffee.csv")

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %% [markdown]
# #Accessing Data with Pandas

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.sample(5)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 1     Monday       Latte          15
# 7   Thursday       Latte          30

# %% [markdown]
# loc - Allows us to filter by rows and columns of data set

# %%
coffee.loc[5:8,["Day"]]
# Out:
#          Day
# 5  Wednesday
# 6   Thursday
# 7   Thursday
# 8     Friday

# %% [markdown]
# iloc -Allows us to acesss the data using index

# %%
coffee.iloc[0:4,0:4]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
# Example of updating the value in "Units Sold" column at index 1
coffee.loc[1, "Units Sold"] = 100

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte         100
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte         100
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[13,["Units Sold"]]=30
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte         100
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          30

# %%
coffee.sort_values(["Coffee Type","Units Sold"],ascending=[1,1])
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          30
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 13     Sunday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 1      Monday       Latte         100

# %%
coffee[coffee["Units Sold"]>30]
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte         100
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45

# %%
coffee[coffee["Coffee Type"].str.contains("Espresso",case=False)]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          30
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %% [markdown]
# ###Adding or Removing columns

# %%
coffee["Price"] = 4.99

# %%
import numpy as np
coffee["New price"] = np.where(coffee["Coffee Type"] == "Espresso", 3.99, 4.99)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  New price
# 0      Monday    Espresso          25   4.99       3.99
# 1      Monday       Latte         100   4.99       4.99
# 2     Tuesday    Espresso          30   4.99       3.99
# 3     Tuesday       Latte          20   4.99       4.99
# 4   Wednesday    Espresso          35   4.99       3.99
# 5   Wednesday       Latte          25   4.99       4.99
# 6    Thursday    Espresso          40   4.99       3.99
# 7    Thursday       Latte          30   4.99       4.99
# 8      Friday    Espresso          45   4.99       3.99
# 9      Friday       Latte          35   4.99       4.99
# 10   Saturday    Espresso          45   4.99       3.99
# 11   Saturday       Latte          35   4.99       4.99
# 12     Sunday    Espresso          45   4.99       3.99
# 13     Sunday       Latte          30   4.99       4.99

# %%
coffee.drop(columns="Price")
# Out:
#           Day Coffee Type  Units Sold  New price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte         100       4.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       4.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       4.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       4.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       4.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       4.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          30       4.99

# %%
coffee["revenue"] = coffee["Units Sold"]*coffee["New price"]
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  New price  revenue
# 0     Monday    Espresso          25   4.99       3.99    99.75
# 1     Monday       Latte         100   4.99       4.99   499.00
# 2    Tuesday    Espresso          30   4.99       3.99   119.70
# 3    Tuesday       Latte          20   4.99       4.99    99.80
# 4  Wednesday    Espresso          35   4.99       3.99   139.65

# %%
coffee = coffee.drop(columns="Price")

# %%
coffee=coffee.rename(columns={'New price':'Price'})

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  revenue
# 0     Monday    Espresso          25   3.99    99.75
# 1     Monday       Latte         100   4.99   499.00
# 2    Tuesday    Espresso          30   3.99   119.70
# 3    Tuesday       Latte          20   4.99    99.80
# 4  Wednesday    Espresso          35   3.99   139.65

# %% [markdown]
# #Adding/Removing Columns

# %%
bios=pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/data/bios.csv")

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new=bios.copy()
bios_new["first_name"]=bios_new["name"].str.split(' ').str[0]

# %%
bios_new.query('first_name == "Keith"')
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# ...

# %%
nocs = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/data/noc_regions.csv")
nocs
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %% [markdown]
# #Merging & Concatenating Data

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios_new = pd.merge(bios,nocs,left_on="born_country",right_on="NOC",how='left')

# %%
bios_new.rename(columns={'region':'born_country_full'},inplace=True)

# %%
bios_new.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country      NOC_x  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date NOC_y born_country_full notes
# 145495         NaN   RUS            Russia   NaN
# ...

# %%
bios_new[bios_new['NOC_x'] != bios_new['born_country_full']][['name',"NOC_x","born_country_full"]]
# Out:
#                        name    NOC_x born_country_full
# 4              Albert Canet   France                UK
# 12                J. Defert   France               NaN
# 13           Étienne Durand   France               NaN
# 16               Guy Forget   France           Morocco
# 27       Guy, Baron Lejeune   France               NaN
# ...                     ...      ...               ...
# 145491        Matthew Wepke  Jamaica               NaN
# 145493   Landysh Falyakhova      ROC            Russia
# 145495    Polina Luchnikova      ROC            Russia
# 145496  Valeriya Merkusheva      ROC            Russia
# 145497      Yuliya Smirnova      ROC            Russia
#
# [73210 rows x 3 columns]

# %%
usa = bios[bios['born_country']=='USA'].copy()
gbr = bios[bios['born_country']=='GBR'].copy()

# %%
usa.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country            NOC  height_cm  weight_kg   died_date
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN

# %%
new_df=pd.concat([usa,gbr])

# %%
new_df.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg died_date
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN

# %% [markdown]
# #Null values

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  revenue
# 0     Monday    Espresso          25   3.99    99.75
# 1     Monday       Latte         100   4.99   499.00
# 2    Tuesday    Espresso          30   3.99   119.70
# 3    Tuesday       Latte          20   4.99    99.80
# 4  Wednesday    Espresso          35   3.99   139.65

# %%
coffee.loc[[0,1],'Units Sold'] = np.nan

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  revenue
# 0     Monday    Espresso         NaN   3.99    99.75
# 1     Monday       Latte         NaN   4.99   499.00
# 2    Tuesday    Espresso        30.0   3.99   119.70
# 3    Tuesday       Latte        20.0   4.99    99.80
# 4  Wednesday    Espresso        35.0   3.99   139.65

# %%
coffee.isnull().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# Price          0
# revenue        0
# dtype: int64

# %%
#coffee.fillna(coffee['Units Sold'].mean())
coffee.fillna(coffee['Units Sold'].interpolate())
# Out:
#           Day Coffee Type  Units Sold  Price  revenue
# 0      Monday    Espresso         NaN   3.99    99.75
# 1      Monday       Latte         NaN   4.99   499.00
# 2     Tuesday    Espresso        30.0   3.99   119.70
# 3     Tuesday       Latte        20.0   4.99    99.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   4.99   124.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   4.99   149.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   4.99   174.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   4.99   174.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        30.0   4.99   149.70

# %%
coffee.loc[[2,3],'Units Sold']=np.nan

# %%
coffee.loc[[0,1],'Units Sold']=15

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  revenue
# 0      Monday    Espresso        15.0   3.99    99.75
# 1      Monday       Latte        15.0   4.99   499.00
# 2     Tuesday    Espresso         NaN   3.99   119.70
# 3     Tuesday       Latte         NaN   4.99    99.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   4.99   124.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   4.99   149.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   4.99   174.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   4.99   174.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        30.0   4.99   149.70

# %%
coffee['Units Sold'].interpolate()
# Out:
# 0     15.000000
# 1     15.000000
# 2     21.666667
# 3     28.333333
# 4     35.000000
# 5     25.000000
# 6     40.000000
# 7     30.000000
# 8     45.000000
# 9     35.000000
# 10    45.000000
# 11    35.000000
# 12    45.000000
# 13    30.000000
# Name: Units Sold, dtype: float64

# %%
coffee.loc[[2,3],'Units Sold']=np.nan
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  revenue
# 0      Monday    Espresso        15.0   3.99    99.75
# 1      Monday       Latte        15.0   4.99   499.00
# 2     Tuesday    Espresso         NaN   3.99   119.70
# 3     Tuesday       Latte         NaN   4.99    99.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   4.99   124.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   4.99   149.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   4.99   174.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   4.99   174.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        30.0   4.99   149.70

# %%
coffee[coffee['Units Sold'].isna()]
# Out:
#        Day Coffee Type  Units Sold  Price  revenue
# 2  Tuesday    Espresso         NaN   3.99    119.7
# 3  Tuesday       Latte         NaN   4.99     99.8

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold  Price  revenue
# 0      Monday    Espresso        15.0   3.99    99.75
# 1      Monday       Latte        15.0   4.99   499.00
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   4.99   124.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   4.99   149.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   4.99   174.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   4.99   174.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        30.0   4.99   149.70

# %% [markdown]
# #Aggregating data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios['born_city'].value_counts()
# Out:
# born_city
# Budapest           1378
# Moskva (Moscow)     883
# Oslo                708
# Stockholm           629
# Praha (Prague)      600
#                    ...
# Bodrogkisfalud        1
# Ternberg              1
# Klaus                 1
# Plaški                1
# Dulwich Hill          1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country']=='USA']['born_region'].value_counts()
# Out:
# born_region
# California              1634
# New York                 990
# Illinois                 585
# Pennsylvania             530
# Massachusetts            530
# New Jersey               381
# Texas                    368
# Minnesota                365
# Ohio                     328
# Michigan                 319
# Washington               240
# Florida                  235
# Wisconsin                209
# Colorado                 207
# Connecticut              156
# Indiana                  150
# Oregon                   132
# Georgia                  129
# Virginia                 121
# Maryland                 117
# District of Columbia     107
# Iowa                     102
# Hawaiʻi                   95
# Kansas                    94
# Oklahoma                  93
# Louisiana                 92
# Utah                      91
# Missouri                  91
# North Carolina            86
# Arizona                   83
# New Hampshire             83
# ...

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    225.0
# Latte       170.0
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type']).agg({'Units Sold':'sum','Price':'mean'})
# Out:
#              Units Sold  Price
# Coffee Type
# Espresso          225.0   3.99
# Latte             170.0   4.99

# %%
coffee.columns
# Out:
# Index(['Day', 'Coffee Type', 'Units Sold', 'Price', 'revenue'], dtype='object')

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  revenue
# 0      Monday    Espresso        15.0   3.99    99.75
# 1      Monday       Latte        15.0   4.99   499.00
# 2     Tuesday    Espresso         NaN   3.99   119.70
# 3     Tuesday       Latte         NaN   4.99    99.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   4.99   124.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   4.99   149.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   4.99   174.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   4.99   174.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        30.0   4.99   149.70

# %%
pivot = coffee.pivot(columns='Coffee Type',index='Day',values='revenue')

# %%
pivot
# Out:
# Coffee Type  Espresso   Latte
# Day
# Friday         179.55  174.65
# Monday          99.75  499.00
# Saturday       179.55  174.65
# Sunday         179.55  149.70
# Thursday       159.60  149.70
# Tuesday        119.70   99.80
# Wednesday      139.65  124.75

# %% [markdown]
# #Advanced Functionality

# %%
coffee['yesterday_revenue']=coffee['revenue'].shift(1)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  revenue  yesterday_revenue
# 0      Monday    Espresso        15.0   3.99    99.75                NaN
# 1      Monday       Latte        15.0   4.99   499.00              99.75
# 2     Tuesday    Espresso         NaN   3.99   119.70             499.00
# 3     Tuesday       Latte         NaN   4.99    99.80             119.70
# 4   Wednesday    Espresso        35.0   3.99   139.65              99.80
# 5   Wednesday       Latte        25.0   4.99   124.75             139.65
# 6    Thursday    Espresso        40.0   3.99   159.60             124.75
# 7    Thursday       Latte        30.0   4.99   149.70             159.60
# 8      Friday    Espresso        45.0   3.99   179.55             149.70
# 9      Friday       Latte        35.0   4.99   174.65             179.55
# 10   Saturday    Espresso        45.0   3.99   179.55             174.65
# 11   Saturday       Latte        35.0   4.99   174.65             179.55
# ...

# %%
coffee['pct_change'] = coffee['revenue']/coffee['yesterday_revenue']*100

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  revenue  yesterday_revenue  \
# 0      Monday    Espresso        15.0   3.99    99.75                NaN
# 1      Monday       Latte        15.0   4.99   499.00              99.75
# 2     Tuesday    Espresso         NaN   3.99   119.70             499.00
# 3     Tuesday       Latte         NaN   4.99    99.80             119.70
# 4   Wednesday    Espresso        35.0   3.99   139.65              99.80
# 5   Wednesday       Latte        25.0   4.99   124.75             139.65
# 6    Thursday    Espresso        40.0   3.99   159.60             124.75
# 7    Thursday       Latte        30.0   4.99   149.70             159.60
# 8      Friday    Espresso        45.0   3.99   179.55             149.70
# 9      Friday       Latte        35.0   4.99   174.65             179.55
# 10   Saturday    Espresso        45.0   3.99   179.55             174.65
# 11   Saturday       Latte        35.0   4.99   174.65             179.55
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios['height_rank']=bios['height_cm'].rank()

# %%
bios.sort_values(['height_rank'],ascending=False)
# Out:
#         athlete_id                   name   born_date           born_city  \
# 89070        89782               Yao Ming  1980-09-12      Xuhui District
# 5781          5804         Tommy Burleson  1952-02-24           Crossnore
# 6978          7013        Arvydas Sabonis  1964-12-19              Kaunas
# 89075        89787         Roberto Dueñas  1975-11-01              Madrid
# 120266      122147           Zhang Zhaoxu  1987-11-18             Binzhou
# ...            ...                    ...         ...                 ...
# 145490      149217            Sin Ye-Chan  1995-06-13                 NaN
# 145491      149218          Matthew Wepke  1989-12-05                 NaN
# 145492      149219  Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova  1998-08-31    Dva Polya Artash
# 145499      149814          Bill Phillips  1913-07-15        Dulwich Hill
#
#                  born_region born_country                         NOC  \
# ...
